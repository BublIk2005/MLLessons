# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Загрузить изобрважение в отттенках серого
image = cv2.imread("images/porsche.jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()
